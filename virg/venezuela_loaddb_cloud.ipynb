# %%
from pymongo import MongoClient
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://xjarodx:Eachtransformlion99@ds163764.mlab.com:63764/heroku_pptb0bm8'
client = MongoClient(conn)

# %%
# Define database and collection
db = client.heroku_pptb0bm8
collection = db.measurements

# %%
# Import CSV file and transform to Pandas DF
df = pd.read_csv("venezuela_explore_data.csv") 
df
# Out:
#          name  index year  overall score  property rights  \
# 0  Venezuela         2019           25.9              7.6
# 1  Venezuela         2018           25.2              5.2
# 2  Venezuela         2017           27.0              6.8
# 3  Venezuela         2016           33.7              5.0
# 4  Venezuela         2015           34.3              5.0
# 5  Venezuela         2014           36.3              5.0
# 6  Venezuela         2013           36.1              5.0
#
#    government integrity  judicial effectiveness  tax burden  \
# 0                   7.9                    13.1        74.7
# 1                   7.5                    13.8        72.5
# 2                  11.6                    10.3        72.5
# 3                  19.0                     NaN        74.9
# 4                  20.0                     NaN        75.0
# 5                  16.5                     NaN        75.3
# 6                  19.0                     NaN        75.6
#
# ...

# %%
# Transform DF to dict
records_ = df.to_dict(orient = 'records')
records_
# Out:
# [{'name': 'Venezuela ',
#   'index year': 2019,
#   'overall score': 25.9,
#   'property rights': 7.6,
#   'government integrity': 7.9,
#   'judicial effectiveness': 13.1,
#   'tax burden': 74.7,
#   'government spending': 58.1,
#   'fiscal health': 17.6,
#   'business freedom': 33.9,
#   'labor freedom': 28.0,
#   'monetary freedom': 0.0,
#   'trade freedom': 60.0,
#   'investment freedom': 0.0,
#   'financial freedom': 10.0},
#  {'name': 'Venezuela ',
#   'index year': 2018,
#   'overall score': 25.2,
#   'property rights': 5.2,
#   'government integrity': 7.5,
#   'judicial effectiveness': 13.8,
#   'tax burden': 72.5,
#   'government spending': 57.3,
#   'fiscal health': 18.4,
#   'business freedom': 35.4,
#   'labor freedom': 24.2,
#   'monetary freedom': 0.0,
#   'trade freedom': 58.7,
#   'investment freedom': 0.0,
#   'financial freedom': 10.0},
#  {'name': 'Venezuela ',
#   'index year': 2017,
#   'overall score': 27.0,
#   'property rights': 6.8,
# ...

# %%
# Load data to mongodb
result = db.measurements.insert_many(records_ )
