# %%
import pandas as pd
from pymongo import MongoClient

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://******:**********@ds163764.mlab.com:63764/heroku_pptb0bm8'
client = MongoClient(conn)

# %%
# Define database and collection
db = client.heroku_pptb0bm8
collection = db.worldbank

# %%
#file to load
worldbank_path='World_Bank_data.csv'

# %%
#read in CSV and store in Pandas df
worldbank_df= pd.read_csv(worldbank_path, encoding="utf-8")
worldbank_df
# Out:
#             Data Source World Development Indicators  \
# 0                   NaN                          NaN
# 1     Last Updated Date                    1/30/2019
# 2                   NaN                          NaN
# 3          Country Name                 Country Code
# 4         Venezuela, RB                          VEN
# 5         Venezuela, RB                          VEN
# 6         Venezuela, RB                          VEN
# 7         Venezuela, RB                          VEN
# 8         Venezuela, RB                          VEN
# 9         Venezuela, RB                          VEN
# 10        Venezuela, RB                          VEN
# 11        Venezuela, RB                          VEN
# 12        Venezuela, RB                          VEN
# 13        Venezuela, RB                          VEN
# 14        Venezuela, RB                          VEN
# 15        Venezuela, RB                          VEN
# 16        Venezuela, RB                          VEN
# ...

# %%
worldbank_df.drop ([0,1,2])
# Out:
#         Data Source World Development Indicators  \
# 3      Country Name                 Country Code
# 4     Venezuela, RB                          VEN
# 5     Venezuela, RB                          VEN
# 6     Venezuela, RB                          VEN
# 7     Venezuela, RB                          VEN
# 8     Venezuela, RB                          VEN
# 9     Venezuela, RB                          VEN
# 10    Venezuela, RB                          VEN
# 11    Venezuela, RB                          VEN
# 12    Venezuela, RB                          VEN
# 13    Venezuela, RB                          VEN
# 14    Venezuela, RB                          VEN
# 15    Venezuela, RB                          VEN
# 16    Venezuela, RB                          VEN
# 17    Venezuela, RB                          VEN
# 18    Venezuela, RB                          VEN
# 19    Venezuela, RB                          VEN
# 20    Venezuela, RB                          VEN
# ...

# %%
worldbank_df.columns
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
clean_df= worldbank_df.drop(['Data Source', 'World Development Indicators',
       'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
       'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
       'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
       'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
       'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
       'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
       'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
       'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56'], axis=1)

# %%
clean_df
# Out:
#                                              Unnamed: 2   Unnamed: 57  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                        Indicator Name  2.013000e+03
# 4     Employment in services, female (% of female em...  8.855000e+01
# 5     Child employment in services (% of economicall...  5.886000e+01
# 6     Child employment in services, male (% of male ...  4.907000e+01
# 7     Child employment in services, female (% of fem...  8.115000e+01
# 8     Children in employment, self-employed (% of ch...  2.739000e+01
# 9     Children in employment, self-employed, male (%...  3.041000e+01
# 10    Children in employment, self-employed, female ...  2.031000e+01
# 11    Child employment in manufacturing (% of econom...  9.370000e+00
# ...

# %%
cleaner_df=clean_df.drop ([0,1,2])
cleaner_df
# Out:
#                                              Unnamed: 2   Unnamed: 57  \
# 3                                        Indicator Name  2.013000e+03
# 4     Employment in services, female (% of female em...  8.855000e+01
# 5     Child employment in services (% of economicall...  5.886000e+01
# 6     Child employment in services, male (% of male ...  4.907000e+01
# 7     Child employment in services, female (% of fem...  8.115000e+01
# 8     Children in employment, self-employed (% of ch...  2.739000e+01
# 9     Children in employment, self-employed, male (%...  3.041000e+01
# 10    Children in employment, self-employed, female ...  2.031000e+01
# 11    Child employment in manufacturing (% of econom...  9.370000e+00
# 12    Child employment in manufacturing, male (% of ...  9.250000e+00
# 13    Child employment in manufacturing, female (% o...  9.660000e+00
# 14    Informal employment (% of total non-agricultur...           NaN
# ...

# %%
cleaner_df.dropna(how='any')
# Out:
#                                              Unnamed: 2   Unnamed: 57  \
# 3                                        Indicator Name  2.013000e+03
# 4     Employment in services, female (% of female em...  8.855000e+01
# 17    Employment in industry (% of total employment)...  2.132600e+01
# 18    Employment in industry, male (% of male employ...  2.871800e+01
# 19    Employment in industry, female (% of female em...  1.012100e+01
# 20        GDP per person employed (constant 2011 PPP $)  4.166141e+04
# 21    Contributing family workers, total (% of total...  2.591000e+00
# 22    Contributing family workers, male (% of male e...  1.864000e+00
# 23    Contributing family workers, female (% of fema...  3.696000e+00
# 27    Wage and salaried workers, total (% of total e...  6.682300e+01
# 28    Wage and salaried workers, male (% of male emp...  6.473300e+01
# 29    Wage and salaried workers, female (% of female...  7.000100e+01
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format
cleaner_df
# Out:
#                                              Unnamed: 2  Unnamed: 57  \
# 3                                        Indicator Name      2013.00
# 4     Employment in services, female (% of female em...        88.55
# 5     Child employment in services (% of economicall...        58.86
# 6     Child employment in services, male (% of male ...        49.07
# 7     Child employment in services, female (% of fem...        81.15
# 8     Children in employment, self-employed (% of ch...        27.39
# 9     Children in employment, self-employed, male (%...        30.41
# 10    Children in employment, self-employed, female ...        20.31
# 11    Child employment in manufacturing (% of econom...         9.37
# 12    Child employment in manufacturing, male (% of ...         9.25
# 13    Child employment in manufacturing, female (% o...         9.66
# 14    Informal employment (% of total non-agricultur...          nan
# 15    Informal employment, male (% of total non-agri...          nan
# ...

# %%
d_df=cleaner_df.dropna(how='any')
d_df
# Out:
#                                              Unnamed: 2    Unnamed: 57  \
# 3                                        Indicator Name        2013.00
# 4     Employment in services, female (% of female em...          88.55
# 17    Employment in industry (% of total employment)...          21.33
# 18    Employment in industry, male (% of male employ...          28.72
# 19    Employment in industry, female (% of female em...          10.12
# 20        GDP per person employed (constant 2011 PPP $)       41661.41
# 21    Contributing family workers, total (% of total...           2.59
# 22    Contributing family workers, male (% of male e...           1.86
# 23    Contributing family workers, female (% of fema...           3.70
# 27    Wage and salaried workers, total (% of total e...          66.82
# 28    Wage and salaried workers, male (% of male emp...          64.73
# 29    Wage and salaried workers, female (% of female...          70.00
# ...

# %%
new_df= d_df.rename(columns={"Unnamed: 2": "Indicator Name", "Unnamed: 57": "2013", "Unnamed: 58": "2014", "Unnamed: 59": "2015", "Unnamed: 60": "2016", "Unnamed: 61": "2017", "Unnamed: 62": "2018"})
new_df
# Out:
#                                          Indicator Name           2013  \
# 3                                        Indicator Name        2013.00
# 4     Employment in services, female (% of female em...          88.55
# 17    Employment in industry (% of total employment)...          21.33
# 18    Employment in industry, male (% of male employ...          28.72
# 19    Employment in industry, female (% of female em...          10.12
# 20        GDP per person employed (constant 2011 PPP $)       41661.41
# 21    Contributing family workers, total (% of total...           2.59
# 22    Contributing family workers, male (% of male e...           1.86
# 23    Contributing family workers, female (% of fema...           3.70
# 27    Wage and salaried workers, total (% of total e...          66.82
# 28    Wage and salaried workers, male (% of male emp...          64.73
# 29    Wage and salaried workers, female (% of female...          70.00
# ...

# %%
almost_df= new_df.drop ([3])
almost_df
# Out:
#                                          Indicator Name           2013  \
# 4     Employment in services, female (% of female em...          88.55
# 17    Employment in industry (% of total employment)...          21.33
# 18    Employment in industry, male (% of male employ...          28.72
# 19    Employment in industry, female (% of female em...          10.12
# 20        GDP per person employed (constant 2011 PPP $)       41661.41
# 21    Contributing family workers, total (% of total...           2.59
# 22    Contributing family workers, male (% of male e...           1.86
# 23    Contributing family workers, female (% of fema...           3.70
# 27    Wage and salaried workers, total (% of total e...          66.82
# 28    Wage and salaried workers, male (% of male emp...          64.73
# 29    Wage and salaried workers, female (% of female...          70.00
# 30    Vulnerable employment, total (% of total emplo...          29.30
# ...

# %%
# Transform DF to dict
records_ = almost_df.to_dict(orient = 'records')

# %%
# Load data to mongodb
result = db.worldbank.insert_many(records_ )
